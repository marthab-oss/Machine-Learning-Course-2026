# %% [markdown]
# <a href="https://colab.research.google.com/github/marthab-oss/Machine-Learning-Course-2026/blob/main/CausalInf_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset: Sequential Mediation from Kaggle

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
print(os.getcwd())
# Out:
# /content

# %%
#import datafile df with pandas
df=pd.read_csv('sequential_mediation_dataset.csv')
df
# Out:
#      educational_intervention  coping_strategy_improvement  \
# 0                           0                     3.298523
# 1                           1                     4.974326
# 2                           0                     3.645984
# 3                           0                     6.857980
# 4                           0                     7.255833
# ..                        ...                          ...
# 495                         1                     7.269944
# 496                         1                     4.909619
# 497                         0                     4.500907
# 498                         1                     8.025659
# 499                         0                     5.691849
#
#      social_support_enhancement  mental_health_score  socioeconomic_status  \
# 0                      4.447087           140.703158              0.496714
# 1                      8.695738           142.482628             -0.138264
# ...

# %%
#overview of data
#sort all coloumns
cols=['educational_intervention','coping_strategy_improvement', 'social_support_enhancement', 'mental_health_score', 'socioeconomic_status','school_quality_score', 'baseline_cognitive_score'] #, 'random_noise'
df_0=df[df['educational_intervention']==0]
df_1=df[df['educational_intervention']==1]
plt.figure(figsize=(11,7))
for a in cols:
  sorted_0=df_0[a].sort_values().reset_index(drop=True)
  sorted_1=df_1[a].sort_values().reset_index(drop=True)
  #distribution of the 5 characteristics (w/o random noise) to intervention 0 or 1
  plt.plot(sorted_0, label=f'{a}(0)')
  plt.plot(sorted_1, label=f'{a}(1)')
  plt.text(len(sorted_0), sorted_0.iloc[-1], f'{a} (0)')


#_0[cols].plot(kind='box', figsize=(15,4))
#df_1[cols].plot(kind='box', figsize=(15,4))
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5091/4207610288.py in <cell line: 0>()
#      14
#      15
# ---> 16 sorted_0[cols].plot(kind='box', figsize=(15,4))
#      17 sorted_1[cols].plot(kind='box', figsize=(15,4))
#      18 plt.tight_layout()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1151             return self._get_rows_with_mask(key)
#    1152
# -> 1153         return self._get_with(key)
#    1154
#    1155     def _get_with(self, key):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _get_with(self, key)
#    1192
#    1193         # handle the dup indexing case GH#4246
# -> 1194         return self.loc[key]
#    1195
#    1196     def _get_values_tuple(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
# ...
